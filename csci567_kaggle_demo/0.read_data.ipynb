# %%
import pandas as pd

# %%
customers_df = pd.read_csv('data/customers.csv')
customers_df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [2], in <cell line: 1>()
# ----> 1 customers_df = pd.read_csv('data/customers.csv')
#       2 customers_df.head()
#
# File ~/Desktop/吴智杰/USC文件/csci 567/final_project/CSCI_id05/venv/lib/python3.9/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...

# %%
print(len(customers_df))
print(customers_df.columns)
# Out:
# 1371980
# Index(['customer_id', 'FN', 'Active', 'club_member_status',
#        'fashion_news_frequency', 'age', 'postal_code'],
#       dtype='object')

# %%
print("FN\n", customers_df.FN.unique(),len(customers_df.FN.unique()))
print("\nActive\n", customers_df.Active.unique(),len(customers_df.Active.unique()))
print("\nclub_member_status\n", customers_df.club_member_status.unique(), len(customers_df.club_member_status.unique()))
print("\nfashion_news_frequency\n", customers_df.fashion_news_frequency.unique(), len(customers_df.fashion_news_frequency.unique()))
print("\nage\n", sorted(customers_df.age.unique()))
print("\npostal_code\n", customers_df.postal_code.unique(), len(customers_df.postal_code.unique()))
# Out:
# FN
#  [nan  1.] 2
#
# Active
#  [nan  1.] 2
#
# club_member_status
#  ['ACTIVE' nan 'PRE-CREATE' 'LEFT CLUB'] 4
#
# fashion_news_frequency
#  ['NONE' 'Regularly' nan 'Monthly' 'None'] 5
#
# age
#  [16.0, 17.0, 18.0, 19.0, 20.0, 21.0, 22.0, 23.0, 24.0, 25.0, 26.0, 27.0, 28.0, 29.0, 30.0, 31.0, 32.0, 33.0, 34.0, 35.0, 38.0, 40.0, 41.0, 45.0, 48.0, 49.0, 52.0, 54.0, nan, 36.0, 37.0, 39.0, 42.0, 43.0, 44.0, 46.0, 47.0, 50.0, 51.0, 53.0, 55.0, 56.0, 57.0, 58.0, 59.0, 60.0, 61.0, 62.0, 63.0, 64.0, 65.0, 66.0, 67.0, 68.0, 69.0, 70.0, 71.0, 72.0, 73.0, 74.0, 75.0, 76.0, 77.0, 78.0, 79.0, 80.0, 81.0, 82.0, 83.0, 84.0, 85.0, 86.0, 87.0, 88.0, 89.0, 90.0, 91.0, 92.0, 93.0, 94.0, 95.0, 96.0, 97.0, 98.0, 99.0]
#
# postal_code
#  ['52043ee2162cf5aa7ee79974281641c6f11a68d276429a91f8ca0d4b6efa8100'
#  '2973abc54daa8a5f8ccfe9362140c63247c5eee03f1d93f4c830291c32bc3057'
#  '64f17e6a330a85798e4998f62d0930d14db8db1c054af6c9090f7dd3e38380dc' ...
# ...

# %%
articles_df = pd.read_csv('data/articles.csv')
articles_df.head()
# Out:
#    article_id  product_code          prod_name  product_type_no  \
# 0   108775015        108775          Strap top              253
# 1   108775044        108775          Strap top              253
# 2   108775051        108775      Strap top (1)              253
# 3   110065001        110065  OP T-shirt (Idro)              306
# 4   110065002        110065  OP T-shirt (Idro)              306
#
#   product_type_name  product_group_name  graphical_appearance_no  \
# 0          Vest top  Garment Upper body                  1010016
# 1          Vest top  Garment Upper body                  1010016
# 2          Vest top  Garment Upper body                  1010017
# 3               Bra           Underwear                  1010016
# 4               Bra           Underwear                  1010016
#
#   graphical_appearance_name  colour_group_code colour_group_name  ...  \
# 0                     Solid                  9             Black  ...
# ...

# %%
print(len(articles_df))
print(articles_df.columns)
# Out:
# 105542
# Index(['article_id', 'product_code', 'prod_name', 'product_type_no',
#        'product_type_name', 'product_group_name', 'graphical_appearance_no',
#        'graphical_appearance_name', 'colour_group_code', 'colour_group_name',
#        'perceived_colour_value_id', 'perceived_colour_value_name',
#        'perceived_colour_master_id', 'perceived_colour_master_name',
#        'department_no', 'department_name', 'index_code', 'index_name',
#        'index_group_no', 'index_group_name', 'section_no', 'section_name',
#        'garment_group_no', 'garment_group_name', 'detail_desc'],
#       dtype='object')

# %%
print("article_id\t", articles_df.article_id.unique(),len(articles_df.article_id.unique()))

print("product_code\t", articles_df.product_code.unique(),len(articles_df.product_code.unique()))
print("prod_name\t", articles_df.prod_name.unique(),len(articles_df.prod_name.unique()))

print("product_type_no\t", articles_df.product_type_no.unique(),len(articles_df.product_type_no.unique()))
print("product_type_name\t", articles_df.product_type_name.unique(),len(articles_df.product_type_name.unique()))

print("graphical_appearance_no\t", articles_df.graphical_appearance_no.unique(),len(articles_df.graphical_appearance_no.unique()))
print("graphical_appearance_name\t", articles_df.graphical_appearance_name.unique(),len(articles_df.graphical_appearance_name.unique()))

print("colour_group_code\t", articles_df.colour_group_code.unique(),len(articles_df.colour_group_code.unique()))
print("colour_group_name\t", articles_df.colour_group_name.unique(),len(articles_df.colour_group_name.unique()))

print("perceived_colour_value_id\t", articles_df.perceived_colour_value_id.unique(),len(articles_df.perceived_colour_value_id.unique()))
print("perceived_colour_value_name\t", articles_df.perceived_colour_value_name.unique(),len(articles_df.perceived_colour_value_name.unique()))

print("perceived_colour_master_id\t", articles_df.perceived_colour_master_id.unique(),len(articles_df.perceived_colour_master_id.unique()))
print("perceived_colour_master_name\t", articles_df.perceived_colour_master_name.unique(),len(articles_df.perceived_colour_master_name.unique()))

print("department_no\t", articles_df.department_no.unique(),len(articles_df.department_no.unique()))
print("department_name\t", articles_df.department_name.unique(),len(articles_df.department_name.unique()))

print("index_code\t", articles_df.index_code.unique(),len(articles_df.index_code.unique()))
print("index_name\t", articles_df.index_name.unique(),len(articles_df.index_name.unique()))

print("index_group_no\t", articles_df.index_group_no.unique(),len(articles_df.index_group_no.unique()))
print("index_group_name\t", articles_df.index_group_name.unique(),len(articles_df.index_group_name.unique()))

print("section_no\t", articles_df.section_no.unique(),len(articles_df.section_no.unique()))
print("section_name\t", articles_df.section_name.unique(),len(articles_df.section_name.unique()))

print("garment_group_no\t", articles_df.garment_group_no.unique(),len(articles_df.garment_group_no.unique()))
print("garment_group_name\t", articles_df.garment_group_name.unique(),len(articles_df.garment_group_name.unique()))

print("detail_desc\t", articles_df.detail_desc.unique(),len(articles_df.detail_desc.unique()))
# Out:
# article_id	 [108775015 108775044 108775051 ... 956217002 957375001 959461001] 105542
# product_code	 [108775 110065 111565 ... 956217 957375 959461] 47224
# prod_name	 ['Strap top' 'Strap top (1)' 'OP T-shirt (Idro)' ... 'Cartwheel dress'
#  'CLAIRE HAIR CLAW' 'Lounge dress'] 45875
# product_type_no	 [253 306 304 302 273 252 254 272  72 532 295 256  73  -1 308 196  74  67
#   87 298  59 286  57 275 255 265  75 307 274 259  69 297  94  81 245  71
#   70  66 264  89 267  91 262  83 277 305  80 263  78 257  93 293 495 515
#   76 260  77  86  82 296 509  68 258 271  85 283 496 161  49 268 276  84
#  299  60 144 270  79 156  95 287 261  90  88 499 100  98  92 289  96 155
#  512 284 291 285 288 300 303 349 511 475 477 351 467 508 503 465 230 504
#  476 326 494 514 498 525 231 492 489 470 102 366 493 762 529 464 389 761
#  468 521 510 523 491 483] 132
# product_type_name	 ['Vest top' 'Bra' 'Underwear Tights' 'Socks' 'Leggings/Tights' 'Sweater'
# ...

# %%
submission_df = pd.read_csv('data/sample_submission.csv')
print("Number of unique customer IDs:", len(submission_df.customer_id.unique()))
submission_df.head()
# Out:
# Number of unique customer IDs: 1371980
#                                          customer_id  \
# 0  00000dbacae5abe5e23885899a1fa44253a17956c6d1c3...
# 1  0000423b00ade91418cceaf3b26c6af3dd342b51fd051e...
# 2  000058a12d5b43e67d225668fa1f8d618c13dc232df0ca...
# 3  00005ca1c9ed5f5146b52ac8639a40ca9d57aeff4d1bd2...
# 4  00006413d8573cd20ed7128e53b7b13819fe5cfc2d801f...
#
#                                           prediction
# 0  0706016001 0706016002 0372860001 0610776002 07...
# 1  0706016001 0706016002 0372860001 0610776002 07...
# 2  0706016001 0706016002 0372860001 0610776002 07...
# 3  0706016001 0706016002 0372860001 0610776002 07...
# 4  0706016001 0706016002 0372860001 0610776002 07...

# %%
submission_df.iloc[0].customer_id
# Out:
# '00000dbacae5abe5e23885899a1fa44253a17956c6d1c3d25f88aa139fdfc657'

# %%
submission_df.iloc[0].prediction
# Out:
# '0706016001 0706016002 0372860001 0610776002 0759871002 0464297007 0372860002 0610776001 0399223001 0706016003 0720125001 0156231001'

# %%
transactions_df = pd.read_csv('data/transactions_train.csv')
transactions_df.head()
# Out:
#         t_dat                                        customer_id  article_id  \
# 0  2018-09-20  000058a12d5b43e67d225668fa1f8d618c13dc232df0ca...   663713001
# 1  2018-09-20  000058a12d5b43e67d225668fa1f8d618c13dc232df0ca...   541518023
# 2  2018-09-20  00007d2de826758b65a93dd24ce629ed66842531df6699...   505221004
# 3  2018-09-20  00007d2de826758b65a93dd24ce629ed66842531df6699...   685687003
# 4  2018-09-20  00007d2de826758b65a93dd24ce629ed66842531df6699...   685687004
#
#       price  sales_channel_id
# 0  0.050831                 2
# 1  0.030492                 2
# 2  0.015237                 2
# 3  0.016932                 2
# 4  0.016932                 2

# %%
print(len(transactions_df))
print(transactions_df.columns)
# Out:
# 31788324
# Index(['t_dat', 'customer_id', 'article_id', 'price', 'sales_channel_id'], dtype='object')

# %%
print("t_dat\t", len(transactions_df.t_dat.unique()))
print("customer_id\t", len(transactions_df.customer_id.unique()))
print("article_id\t", len(transactions_df.article_id.unique()))
print("sales_channel_id\t",  transactions_df.sales_channel_id.unique(), len(transactions_df.sales_channel_id.unique()))
# Out:
# t_dat	 734
# customer_id	 1362281
# article_id	 104547
# sales_channel_id	 [2 1] 2
